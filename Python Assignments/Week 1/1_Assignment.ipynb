# %% [markdown]
# Q1. Create one variable containing following type of data:
# (i) string
# (ii) list
# (iii) float
# (iv) tuple

# %%
var 1 = "String"
var 2 = [1,2,3,4,5,6]
var 3 = 27.9
var 4 = (1,2,3,4,5)

# %% [markdown]
# Q2. Given are some following variables containing data:
# (i) var1 = ‘ ‘
# (ii) var2 = ‘[ DS , ML , Python]’
# (iii) var3 = [ ‘DS’ , ’ML’ , ‘Python’ ]
# (iv) var4 = 1.
# What will be the data type of the above given variable.

# %%
var1 = '' 
var2 = '[ DS , ML , Python]'
var3 = [ 'DS' , 'ML' , 'Python' ] 
var4 = 1
print(type(var1))
print(type(var2))
print(type(var3))
print(type(var4))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'list'>
# <class 'int'>

# %% [markdown]
# Q3. Explain the use of the following operators using an example:
# (i) /
# (ii) %
# (iii) //
# (iv) **

# %%
a = 10
b = 5
print(a/b) #Division
print(a%b) #Modulus
print(a//b) #Floor division
print(a**b) #Exponentiation

# %% [markdown]
# Q4. Create a list of length 10 of your choice containing multiple types of data. Using for loop print the
# element and its data type.

# %%
l = ['Prasad', 9, 25.10, (1,2,3,4,5), {6,7,8}, True, 8+7j, [9,10,11], {"Course" : 'Data Science Masters'}, None]
for i in l :
    print(i)
    print(type(i))
    print("----------")
# Out:
# Prasad
# <class 'str'>
# ----------
# 9
# <class 'int'>
# ----------
# 25.1
# <class 'float'>
# ----------
# (1, 2, 3, 4, 5)
# <class 'tuple'>
# ----------
# {8, 6, 7}
# <class 'set'>
# ----------
# True
# <class 'bool'>
# ----------
# (8+7j)
# <class 'complex'>
# ----------
# [9, 10, 11]
# <class 'list'>
# ----------
# {'Course': 'Data Science Masters'}
# <class 'dict'>
# ----------
# None
# <class 'NoneType'>
# ----------

# %% [markdown]
# Q5. Using a while loop, verify if the number A is purely divisible by number B and if so then how many
# times it can be divisible.

# %%
a = 360
b = 9
i = 0
while a % b == 0 :
    a = a // b
    i = i + 1
if i > 0 :
    print(f"a is purely divible by b and it can be divided {i} times")
else :
    print("a is not divisible by b")
# Out:
# a is purely divible by b and it can be divided 1 times

# %% [markdown]
# Q6. Create a list containing 25 int type data. Using for loop and if-else condition print if the element is
# divisible by 3 or not.

# %%
l = list(range(1,26))
for i in l :
    if i % 3 == 0 :
        print(i , "is divisible by 3")
    else :
        print(i, "is not divisible by 3")
# Out:
# 1 is not divisible by 3
# 2 is not divisible by 3
# 3 is divisible by 3
# 4 is not divisible by 3
# 5 is not divisible by 3
# 6 is divisible by 3
# 7 is not divisible by 3
# 8 is not divisible by 3
# 9 is divisible by 3
# 10 is not divisible by 3
# 11 is not divisible by 3
# 12 is divisible by 3
# 13 is not divisible by 3
# 14 is not divisible by 3
# 15 is divisible by 3
# 16 is not divisible by 3
# 17 is not divisible by 3
# 18 is divisible by 3
# 19 is not divisible by 3
# 20 is not divisible by 3
# 21 is divisible by 3
# 22 is not divisible by 3
# 23 is not divisible by 3
# 24 is divisible by 3
# 25 is not divisible by 3

# %% [markdown]
# Q7. What do you understand about mutable and immutable data types? Give examples for both showing
# this property.

# %%
list = [1,2,3,4,5,6,7,8] #A mutable object can be changed after it is created.

# %%
list[2] = 10

# %%
list
# Out:
# [1, 2, 10, 4, 5, 6, 7, 8]

# %% [markdown]
# Here , we can see that the list is modified

# %%
tuple = (1,2,3,4,5,6,7,8) #An immutable object cannot be changed after it is created.

# %%
tuple[2] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 tuple[2] = 10
#
# TypeError: 'tuple' object does not support item assignment
